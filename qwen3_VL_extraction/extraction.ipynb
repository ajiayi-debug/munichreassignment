# %% [markdown]
# <a href="https://colab.research.google.com/github/ajiayi-debug/munichreassignment/blob/main/extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PDF Extraction with Qwen3 VL
#
# This notebook extracts text and layout information from PDF documents using the Qwen3 8B vision-language model.

# %% [markdown]
# ## Setup (Google Colab)
#
# Install required dependencies for Qwen3-VL model and mount drive for PDF. Make sure to save the PDF in your drive root (MyDrive).
#
# If you would like to use a different PDF< make sure to change the name of the PDF in pdf_path!!!

# %%
from google.colab import drive
drive.mount('/content/drive')

pdf_path="/content/drive/MyDrive/Principles of Public Health.pdf"
output_dir="/content/drive/MyDrive/pdf_extraction"
# Out:
# Mounted at /content/drive

# %%
import os

output_dir="/content/drive/MyDrive/pdf_extraction"
os.makedirs(output_dir, exist_ok=True)
print(f"Output directory ensured at: {output_dir}")
# Out:
# Output directory ensured at: /content/drive/MyDrive/pdf_extraction

# %%
# Install system dependencies for PDF processing
# !apt-get install -y poppler-utils
# !pip install git+https://github.com/huggingface/transformers
# !pip install pdf2image
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 41 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.12 [186 kB]
# Fetched 186 kB in 1s (178 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 121689 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.12_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.12) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.12) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-alteg6m1
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-alteg6m1
#   Resolved https://github.com/huggingface/transformers to commit 5a67f0a7aca8c18de6235e80e47fd00a9ecf9d58
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting huggingface-hub<2.0,>=1.3.0 (from transformers==5.0.1.dev0)
#   Downloading huggingface_hub-1.3.5-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.1.dev0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.1.dev0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.1.dev0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.1.dev0) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.1.dev0) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.1.dev0) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.1.dev0) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.1.dev0) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (0.28.1)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (1.5.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (4.15.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->transformers==5.0.1.dev0) (8.3.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (0.16.0)
# Downloading huggingface_hub-1.3.5-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 15.0 MB/s eta 0:00:00
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-5.0.1.dev0-py3-none-any.whl size=11269591 sha256=a50d13c009ad83a9de59bd8b91be28cda8d53b1d4774535ff79bf98fcd2b1d63
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6lvixtyv/wheels/49/a7/50/c9fdabbf10e51bb1256adb0c1a587fedd7184f5bad28d47fe3
# Successfully built transformers
# Installing collected packages: huggingface-hub, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.36.0
#     Uninstalling huggingface-hub-0.36.0:
#       Successfully uninstalled huggingface-hub-0.36.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.6
#     Uninstalling transformers-4.57.6:
#       Successfully uninstalled transformers-4.57.6
# Successfully installed huggingface-hub-1.3.5 transformers-5.0.1.dev0
# Collecting pdf2image
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from pdf2image) (11.3.0)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.17.0

# %%
import os
import torch
import json
from pathlib import Path
from pdf2image import convert_from_path
from transformers import Qwen3VLForConditionalGeneration, AutoProcessor

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %% [markdown]
# ## Load Qwen3-VL Model
#
# Load the Qwen3-VL-8B-Instruct model and processor.
#
# Make sure to insert your huggingface token into secrets and name it HF_TOKEN. You can get your huggingface token from here:
# https://huggingface.co/settings/tokens

# %%
from google.colab import userdata
token=userdata.get("HF_TOKEN")

# %%
from transformers import AutoProcessor, AutoModelForImageTextToText

model_name = "Qwen/Qwen3-VL-8B-Instruct"

processor = AutoProcessor.from_pretrained(model_name, token=token)
model = AutoModelForImageTextToText.from_pretrained(
    model_name,
    torch_dtype=torch.bfloat16,
    device_map="auto",
    token=token
)

print("Qwen3-VL model loaded successfully!")
# Out:
# preprocessor_config.json:   0%|          | 0.00/390 [00:00<?, ?B/s]
# chat_template.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# video_preprocessor_config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/750 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/269 [00:00<?, ?B/s]
# Qwen3-VL model loaded successfully!

# %% [markdown]
# ## Extraction
#
# Given it is a VLM, I was able to request for extraction of images in terms of description and how it relates to the text, which aids in adding context to the chatbot

# %%
prompt = """Please extract all the text content from this PDF page image.

Extract the following information:
1. All text content in reading order
2. Tables (format as markdown tables)
3. Headings and their hierarchy
4. Lists and bullet points
5. Any formulas or equations
6. Any Images, describe the images and what you can extract from them in terms of relevancy to the text

Organize the output in a clear, structured format that maintains the original document's layout and hierarchy. Return in markdown format"""

# %% [markdown]
# ## Convert PDF to Images
#
# Convert the PDF file into individual page images for processing.

# %%
print(f"Converting PDF to images: {pdf_path}")
images = convert_from_path(pdf_path)
print(f"Total pages: {len(images)}")
# Out:
# Converting PDF to images: /content/drive/MyDrive/Principles of Public Health.pdf
# Total pages: 123

# %% [markdown]
# ## Process Each Page
#
# Loop through each page and extract layout and text information using Qwen3 8B VLM.

# %%
# Process Each Page with Checkpointing
page_outputs = []
output_dir_path = Path(output_dir)

# Ensure the directory exists
output_dir_path.mkdir(parents=True, exist_ok=True)

print(f"Processing {len(images)} pages with checkpointing...")

for page_num, image in enumerate(images, start=1):
    # Define the output path for this specific page
    page_output_path = output_dir_path / f"page_{page_num}_extraction.txt"

    #CHECKPOINT: Check if this page is already done
    if page_output_path.exists():
        print(f"✓ Page {page_num} already exists. Skipping processing.")
        with open(page_output_path, "r", encoding="utf-8") as f:
             # Skip the first line ("=== Page X ===") to avoid duplication if re-printing
             content = f.read()
             page_outputs.append({"page": page_num, "output": content})
        continue

    print(f"\nProcessing page {page_num}/{len(images)}...")

    # Save temp image for the model to read
    temp_image_path = output_dir_path / f"temp_page_{page_num}.png"
    image.save(temp_image_path)
    messages = [
        {
            "role": "user",
            "content": [
                {
                    "type": "image",
                    "image": str(temp_image_path)
                },
                {"type": "text", "text": prompt}
            ]
        }
    ]
    text = processor.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )
    inputs = processor(
        text=[text],
        images=[image],
        padding=True,
        return_tensors="pt",
    )

    # Move to GPU
    device = "cuda" if torch.cuda.is_available() else "cpu"
    inputs = inputs.to(device)

    # Generate output
    generated_ids = model.generate(**inputs, max_new_tokens=4096)
    generated_ids_trimmed = [
        out_ids[len(in_ids):] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
    ]
    output_text = processor.batch_decode(
        generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False
    )[0]
    with open(page_output_path, "w", encoding="utf-8") as f:
        f.write(f"=== Page {page_num} ===\n\n")
        f.write(output_text)
    page_outputs.append({
        "page": page_num,
        "output": output_text
    })

    temp_image_path.unlink()

    print(f"✓ Page {page_num} saved/completed")
    print(f"Preview: {output_text[:100]}...")
# Out:
# Processing 123 pages with checkpointing...
# ✓ Page 1 already exists. Skipping processing.
# ✓ Page 2 already exists. Skipping processing.
# ✓ Page 3 already exists. Skipping processing.
# ✓ Page 4 already exists. Skipping processing.
# ✓ Page 5 already exists. Skipping processing.
# ✓ Page 6 already exists. Skipping processing.
# ✓ Page 7 already exists. Skipping processing.
# ✓ Page 8 already exists. Skipping processing.
# ✓ Page 9 already exists. Skipping processing.
# ✓ Page 10 already exists. Skipping processing.
# ✓ Page 11 already exists. Skipping processing.
# ✓ Page 12 already exists. Skipping processing.
# ✓ Page 13 already exists. Skipping processing.
# ✓ Page 14 already exists. Skipping processing.
# ✓ Page 15 already exists. Skipping processing.
# ✓ Page 16 already exists. Skipping processing.
# ✓ Page 17 already exists. Skipping processing.
# ✓ Page 18 already exists. Skipping processing.
# ✓ Page 19 already exists. Skipping processing.
# ✓ Page 20 already exists. Skipping processing.
# ✓ Page 21 already exists. Skipping processing.
# ✓ Page 22 already exists. Skipping processing.
# ✓ Page 23 already exists. Skipping processing.
# ✓ Page 24 already exists. Skipping processing.
# ✓ Page 25 already exists. Skipping processing.
# ✓ Page 26 already exists. Skipping processing.
# ✓ Page 27 already exists. Skipping processing.
# ✓ Page 28 already exists. Skipping processing.
# ✓ Page 29 already exists. Skipping processing.
# ✓ Page 30 already exists. Skipping processing.
# ✓ Page 31 already exists. Skipping processing.
# ✓ Page 32 already exists. Skipping processing.
# ✓ Page 33 already exists. Skipping processing.
# ✓ Page 34 already exists. Skipping processing.
# ✓ Page 35 already exists. Skipping processing.
# ✓ Page 36 already exists. Skipping processing.
# ✓ Page 37 already exists. Skipping processing.
# ✓ Page 38 already exists. Skipping processing.
# ✓ Page 39 already exists. Skipping processing.
# ✓ Page 40 already exists. Skipping processing.
# ✓ Page 41 already exists. Skipping processing.
# ✓ Page 42 already exists. Skipping processing.
# ✓ Page 43 already exists. Skipping processing.
# ✓ Page 44 already exists. Skipping processing.
# ✓ Page 45 already exists. Skipping processing.
# ✓ Page 46 already exists. Skipping processing.
# ✓ Page 47 already exists. Skipping processing.
# ✓ Page 48 already exists. Skipping processing.
# ✓ Page 49 already exists. Skipping processing.
# ✓ Page 50 already exists. Skipping processing.
# ✓ Page 51 already exists. Skipping processing.
# ✓ Page 52 already exists. Skipping processing.
# ✓ Page 53 already exists. Skipping processing.
# ✓ Page 54 already exists. Skipping processing.
# ✓ Page 55 already exists. Skipping processing.
# ✓ Page 56 already exists. Skipping processing.
# ✓ Page 57 already exists. Skipping processing.
# ✓ Page 58 already exists. Skipping processing.
# ✓ Page 59 already exists. Skipping processing.
# ✓ Page 60 already exists. Skipping processing.
# ✓ Page 61 already exists. Skipping processing.
# ✓ Page 62 already exists. Skipping processing.
# ✓ Page 63 already exists. Skipping processing.
# ✓ Page 64 already exists. Skipping processing.
# ✓ Page 65 already exists. Skipping processing.
# ✓ Page 66 already exists. Skipping processing.
# ✓ Page 67 already exists. Skipping processing.
# ✓ Page 68 already exists. Skipping processing.
#
# Processing page 69/123...
# ✓ Page 69 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 70/123...
# ✓ Page 70 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 71/123...
# ✓ Page 71 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 72/123...
# ✓ Page 72 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 73/123...
# ✓ Page 73 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 74/123...
# ✓ Page 74 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 75/123...
# ✓ Page 75 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 76/123...
# ✓ Page 76 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 77/123...
# ✓ Page 77 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 78/123...
# ✓ Page 78 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 79/123...
# ✓ Page 79 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 80/123...
# ✓ Page 80 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 81/123...
# ✓ Page 81 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 82/123...
# ✓ Page 82 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 83/123...
# ✓ Page 83 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 84/123...
# ✓ Page 84 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 85/123...
# ✓ Page 85 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 86/123...
# ✓ Page 86 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 87/123...
# ✓ Page 87 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 88/123...
# ✓ Page 88 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 89/123...
# ✓ Page 89 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 90/123...
# ✓ Page 90 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 91/123...
# ✓ Page 91 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 92/123...
# ✓ Page 92 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 93/123...
# ✓ Page 93 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 94/123...
# ✓ Page 94 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 95/123...
# ✓ Page 95 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 96/123...
# ✓ Page 96 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 97/123...
# ✓ Page 97 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 98/123...
# ✓ Page 98 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM
#
# The Project Gutenberg eBook of Principles of Public Health, by Thomas ...
#
# Processing page 99/123...
# ✓ Page 99 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 100/123...
# ✓ Page 100 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 101/123...
# ✓ Page 101 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 102/123...
# ✓ Page 102 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM
#
# The Project Gutenberg eBook of Principles of Public Health, by Thomas ...
#
# Processing page 103/123...
# ✓ Page 103 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 104/123...
# ✓ Page 104 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 105/123...
# ✓ Page 105 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 106/123...
# ✓ Page 106 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 107/123...
# ✓ Page 107 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM
#
# The Project Gutenberg eBook of Principles of Public Health, by Thomas ...
#
# Processing page 108/123...
# ✓ Page 108 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 109/123...
# ✓ Page 109 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 110/123...
# ✓ Page 110 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 111/123...
# ✓ Page 111 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 112/123...
# ✓ Page 112 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 113/123...
# ✓ Page 113 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 114/123...
# ✓ Page 114 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 115/123...
# ✓ Page 115 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 116/123...
# ✓ Page 116 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 117/123...
# ✓ Page 117 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 118/123...
# ✓ Page 118 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 119/123...
# ✓ Page 119 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 120/123...
# ✓ Page 120 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 121/123...
# ✓ Page 121 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 122/123...
# ✓ Page 122 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...
#
# Processing page 123/123...
# ✓ Page 123 saved/completed
# Preview: ```markdown
# 1/21/26, 2:50 PM The Project Gutenberg eBook of Principles of Public Health, by Thomas T...

# %% [markdown]
# ## Save Results
#
# Save extracted text from all pages into individual files and a combined file.

# %%
# Combine Extraction Results
# This reads the actual files from disk.

print("Generating full extraction file from checkpoints...")

output_dir_path = Path(output_dir)
combined_output_path = output_dir_path / "full_extraction.txt"

with open(combined_output_path, "w", encoding="utf-8") as outfile:
    # Iterate through the total count of images to maintain order
    for i in range(len(images)):
        page_num = i + 1
        page_file_path = output_dir_path / f"page_{page_num}_extraction.txt"

        outfile.write(f"\n{'='*60}\n")
        outfile.write(f"PAGE {page_num}\n")
        outfile.write(f"{'='*60}\n\n")

        if page_file_path.exists():
            with open(page_file_path, "r", encoding="utf-8") as infile:
                # Read the file content
                content = infile.read()
                lines = content.split('\n')
                if lines and lines[0].startswith("=== Page"):
                    content = "\n".join(lines[2:]) # Skip header and first newline

                outfile.write(content)
        else:
            outfile.write(f"[ERROR: Page {page_num} extraction file not found]\n")

        outfile.write("\n\n")

print(f"✓ Combined output saved to: {combined_output_path}")
print("=== Extraction Complete ===")
# Out:
# Generating full extraction file from checkpoints...
# ✓ Combined output saved to: /content/drive/MyDrive/pdf_extraction/full_extraction.txt
# === Extraction Complete ===
